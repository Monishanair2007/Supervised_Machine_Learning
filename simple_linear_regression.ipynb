# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, root_mean_squared_error

# %%
#homogeneous
x= np.array([1,2,3,4,5])
y = np.array([3,6,9,12,15])

# %%
print(x)
# Out:
# [1 2 3 4 5]

# %%
print(y)
# Out:
# [ 3  6  9 12 15]

# %%
#reshape a function
x1 = np.reshape(x, (-1, 1))
print(x1)
print(x1.shape)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
# (5, 1)

# %%
model.fit(x1 , y)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x1)

# %%
#MSE
mean_squared_error(y, y_predict)
# Out:
# 2.0510383535746308e-30

# %%
#RMSE
root_mean_squared_error(y , y_predict)
# Out:
# 1.4321446692197793e-15

# %%
#r2
r2_score(y , y_predict)
# Out:
# 1.0

# %%
#plot
plt.scatter(x1, y)
plt.plot(x1, y_predict, color='red')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title('Simple Linear Regression')
plt.show()

# %%
#y =mx +c equation
print("Intercept: ", model.intercept_)
print("Coefficient: ", model.coef_[0])
print(f"Equation : Y = {model.intercept_:.2e} + {model.coef_[0].round(2)}X ")
# Out:
# Intercept:  -3.552713678800501e-15
# Coefficient:  3.000000000000001
# Equation : Y = -3.55e-15 + 3.0X

# %% [markdown]
# train & test

# %%
x1_train , x1_test , y1_train , y1_test = train_test_split(x1, y, test_size=0.5, random_state=42)

# %%
model1 = LinearRegression()

# %%
model1.fit(x1_train , y1_train)
# Out:
# LinearRegression()

# %%
y1_predict = model1.predict(x1_test)

# %%
#mean squared error , root mean squared error, r2 score
print("RMSE : " , root_mean_squared_error(y1_test , y1_predict))
print("MSE : " ,mean_squared_error(y1_test , y1_predict))
print("R2 : " , r2_score(y1_test , y1_predict))
# Out:
# RMSE :  0.0
# MSE :  0.0
# R2 :  1.0

# %%
#plot
plt.scatter(x1_test, y1_test)
plt.plot(x1_test, y1_predict, color='red')
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title('Simple Linear Regression ')
plt.show()

# %%
#Mean Squared Error
mse = mean_squared_error(y1_test, y1_predict)
print("mean squared error:", mse)
# Out:
# mean squared error: 0.0

# %%
#root mean squared error
rmse = np.sqrt(mse)
print("root mean squared error:", rmse)
# Out:
# root mean squared error: 0.0

# %%
# R2 error
r2 = r2_score(y1_test, y1_predict)
print("R2 Score:", r2)
r2_error = 1 - r2
print("R2 Error:", r2_error)
# Out:
# R2 Score: 1.0
# R2 Error: 0.0

# %%
#simple linear regression form
print("Intercept: ", model1.intercept_)
print("Coefficient: ", model1.coef_[0])
print(f"Equation : Y = {model1.intercept_:.2e} + {model1.coef_[0].round(2)}X ")
# Out:
# Intercept:  8.881784197001252e-16
# Coefficient:  2.9999999999999996
# Equation : Y = 8.88e-16 + 3.0X
